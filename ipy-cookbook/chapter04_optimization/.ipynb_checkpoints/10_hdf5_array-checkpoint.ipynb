# %% [markdown]
# # HDF5とPyTablesによる巨大配列の操作
# 　NumPy配列等の配列データを永続化する方法を考える。配列の要素数が小さい場合、np.savetxt,np.save,np.savezなどNumPy組み込みの関数で処理できる。しかし要素数が10億を超える配列は、メモリに読み込むには巨大すぎる。
#
# 　その代替策がメモリマップだ。配列はファイルに格納され、CPUが必要となった部分が選択的にメモリに読み込まれる(オーバーレイ?)。
#
# 　ここでは、巨大なデータセットを扱うためのデザインされたPyTablesを使う。これは、[HDF5(Hierarchical Data Format)](https://support.hdfgroup.org/HDF5/)と呼ばれる広く使われているオープンなファイルフォーマットを通して高速なメモリマップを実装している。HDF5ファイルは、POSIX風の階層構造の中に複数のデータセットを格納できる。不必要なシステムメモリの消費を避けながら、データセットのどの部分でも効率的で簡単なアクセスが可能。
#
# ## 準備
# 　PyTables3.0以降が必要。Anacondaを使用している場合、
# ```
# conda install tables
# ```
# でPyTablesをインストールできる。
#
# ## 手順
#
# ### NumPyとPyTablesのインポート

# %%
import numpy as np
import tables as tb

# %% [markdown]
# ### 空のHDF5ファイルを作成

# %%
f = tb.open_file('myfile.h5', 'w')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-12ffbab22357> in <module>()
# ----> 1 f = tb.open_file('myfile.h5', 'w')
#
# /home/ubuntum/anaconda3/lib/python3.6/site-packages/tables/file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     315                 raise ValueError(
#     316                     "The file '%s' is already opened.  Please "
# --> 317                     "close it before reopening in write mode." % filename)
#     318
#     319     # Finally, create the File instance, and return it
#
# ValueError: The file 'myfile.h5' is already opened.  Please close it before reopening in write mode.

# %% [markdown]
# ### 階層のトップレベルグループexperiment1を作成

# %%
f.create_group('/', 'experiment1')
# Out:
# ---------------------------------------------------------------------------
# NodeError                                 Traceback (most recent call last)
# <ipython-input-6-c3d74e34e27a> in <module>()
# ----> 1 f.create_group('/', 'experiment1')
#
# /home/ubuntum/anaconda3/lib/python3.6/site-packages/tables/file.py in create_group(self, where, name, title, filters, createparents)
#     946         _checkfilters(filters)
#     947         return Group(parentnode, name,
# --> 948                      title=title, new=True, filters=filters)
#     949
#     950
#
# /home/ubuntum/anaconda3/lib/python3.6/site-packages/tables/group.py in __init__(self, parentnode, name, title, new, filters, _log)
#     233
#     234         # Finally, set up this object as a node.
# --> 235         super(Group, self).__init__(parentnode, name, _log)
#     236
#     237     def _g_post_init_hook(self):
#
# /home/ubuntum/anaconda3/lib/python3.6/site-packages/tables/node.py in __init__(self, parentnode, name, _log)
#     255             # Only new nodes need to be referenced.
#     256             # Opened nodes are already known by their parent group.
# --> 257             parentnode._g_refnode(self, name, validate)
#     258         self._g_set_location(parentnode, name)
#     259
#
# /home/ubuntum/anaconda3/lib/python3.6/site-packages/tables/group.py in _g_refnode(self, childnode, childname, validate)
#     514             raise NodeError(
#     515                 "group ``%s`` already has a child node named ``%s``"
# --> 516                 % (self._v_pathname, childname))
#     517
#     518         # Show a warning if there is an object attribute with that name.
#
# NodeError: group ``/`` already has a child node named ``experiment1``

# %% [markdown]
# ### experiment1にメタデータを追加

# %%
f.set_node_attr('/experiment1', 'data', '2014-09-01')

# %% [markdown]
# ### グループ内に、1000＊1000の配列array1を格納

# %%
x = np.random.rand(1000, 1000)
f.create_array('/experiment1', 'array1', x)
# Out:
# /experiment1/array1 (Array(1000, 1000)) ''
#   atom := Float64Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := None

# %% [markdown]
# ### ファイルをクローズして、変更をコミット

# %%
f.close()

# %% [markdown]
# ### 保存HDF5ファイルをオープン

# %%
f = tb.open_file('myfile.h5', 'r')

# %% [markdown]
# ### data要素を取り出してみる

# %%
f.get_node_attr('/experiment1', 'data')
# Out:
# '2014-09-01'

# %% [markdown]
# ### ファイル内パス指定、アクセス
# ルート(/)を起点としてファイル内のパスにアクセスできる。rootから"/"を"."に置き換えてパス指定。

# %%
y = f.root.experiment1.array1
# /experiment1/array1
type(y)
# Out:
# tables.array.Array

# %% [markdown]
# ### 配列の操作性
# NumPyの配列としても操作可能。通常のNumPy配列よりメモリの使用効率は高くなる。

# %%
np.array_equal(x[0,:], y[0,:])
# Out:
# True

# %% [markdown]
# ### 絶対パスの利点
# ノードのパスが実行時に判明するような状況では、絶対パスからノードにアクセスする方法が有効となる。

# %%
f.get_node('/experiment1/array1')
# Out:
# /experiment1/array1 (Array(1000, 1000)) ''
#   atom := Float64Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := None

# %% [markdown]
# ### 更新＆ファイル削除

# %%
f.close()

# %%
import os
os.remove('myfile.h5')
